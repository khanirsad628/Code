# %%
import pandas as pd

# %%
df1 = pd.read_csv('DATA.dat',header=None,sep='\t')

# %%
df1.columns = df1.iloc[0].tolist()

# %%
df = pd.read_csv('DATA1.dat',header=None,sep='\t')
df.columns = df.iloc[0].tolist()
df
# Out:
#           id  first_name  last_name                         email  \
# 0         id  first_name  last_name                         email
# 1          1        Inge   Reinisch             ireinisch0@ft.com
# 2          2     Therine    Chalice             tchalice1@mapy.cz
# 3          3        Linn  Carragher            lcarragher2@go.com
# 4          4       Daven   Stennine     dstennine3@shareasale.com
# ...      ...         ...        ...                           ...
# 27996  11752     Raimund     Cowitz        rcowitzrn@usatoday.com
# 27997  11459     Ladonna  Jurgensen         ljurgensenro@time.com
# 27998  11840     Arlinda     Bellas          abellasrp@sbwire.com
# 27999  11501      Deonne     Conkay             dconkayrq@last.fm
# 28000  11635   Alisander  Bartolijn  abartolijnrr@liveinternet.ru
#
#                             job_title  basic_salary  allowances
# 0                           job_title  basic_salary  allowances
# ...

# %%
df.drop_duplicates()
df.drop_duplicates(subset='id', keep='first')
# Out:
#           id  first_name  last_name                         email  \
# 0         id  first_name  last_name                         email
# 1          1        Inge   Reinisch             ireinisch0@ft.com
# 2          2     Therine    Chalice             tchalice1@mapy.cz
# 3          3        Linn  Carragher            lcarragher2@go.com
# 4          4       Daven   Stennine     dstennine3@shareasale.com
# ...      ...         ...        ...                           ...
# 27992  11645      Harman     Lafont           hlafontrj@amazon.de
# 27994  11019     Pernell    Stanton          pstantonrl@alexa.com
# 27996  11752     Raimund     Cowitz        rcowitzrn@usatoday.com
# 27998  11840     Arlinda     Bellas          abellasrp@sbwire.com
# 28000  11635   Alisander  Bartolijn  abartolijnrr@liveinternet.ru
#
#                             job_title  basic_salary  allowances
# 0                           job_title  basic_salary  allowances
# ...
